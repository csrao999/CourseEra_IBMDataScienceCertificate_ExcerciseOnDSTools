# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Create a markdown cell with the title of the notebook. (1 pt)

# %% [markdown]
# ## Peer-graded Assignment: Submit Your Work and Grade Your Peers

# %% [markdown]
# ### Exercise 3 - Create a markdown cell for an introduction. (1 pt)

# %% [markdown]
# ## This is an introductory section and the exercise questions follow as below

# %% [markdown]
# ### Exercise 4 - Create a markdown cell to list data science languages. (3 pts)

# %% [markdown]
# ## LIST OF DATA SCIENCE LANGUAGES
#
# ### Python
# ### R
# ### SQL
# ### Java
# ### Julia
# ### Scala
# ### C/C++
# ### JavaScript
# ### Swift
# ### Go
# ### MATLAB
# ### SAS

# %% [markdown]
# ### Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)

# %% [markdown]
# ## LIST OF DATA SCIENCE LIBRARIES ARE AS BELOW
# TensorFlow
# NumPy
# SciPy
# Pandas
# Matplotlib
# Keras
# SciKit-Learn
# PyTorch
# Scrapy
# BeautifulSoup
# LightGBM
# ELI5
# Theano
# NuPIC
# Ramp
# Pipenv
# Bob
# PyBrain
# Caffe2
# Chainer

# %% [markdown]
# ## Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)

# %%
from tabulate import tabulate

# %%
from tabulate import tabulate

table = [["Matplotlib"],["NumPy"],["Pandas"],["ScikitLearn"],["Scrapy"],
["Knime"],
["Weka"],
["Apache Hadoop "],
["TensorFlow"],
["Apache Spark"],
["Tableau"],
["RapidMiner"],
["MatLab"],
["SAS"]]

print(tabulate(table))
# Out:
# -------------
# Matplotlib
# NumPy
# Pandas
# ScikitLearn
# Scrapy
# Knime
# Weka
# Apache Hadoop
# TensorFlow
# Apache Spark
# Tableau
# RapidMiner
# MatLab
# SAS
# -------------

# %% [markdown]
# ## Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)

# %%
a = 10
b = 20

a + b
# Out:
# 30

# %%
a - b
# Out:
# -10

# %%
a * b
# Out:
# 200

# %%
a / b
# Out:
# 0.5

# %%
a % b
# Out:
# 10

# %%
a ** b
# Out:
# 100000000000000000000

# %% [markdown]
# ## Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)

# %%
a = 10
b = 20

print(a + b)
print(a * b)
# Out:
# 30
# 200

# %% [markdown]
# ## Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %%
min=120

hrs = int(min/60)
print(hrs)
# Out:
# 2

# %% [markdown]
# ## Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)

# %% [markdown]
# ## The objective of this part of the course is to learn about various Data science related Tools, its features and usage.

# %% [markdown]
# ## Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
# ### Author : Chetan Singade

# %% [markdown]
# ## Exercise 12 - Share your notebook through GitHub (3 pts)

# %% [markdown]
# ## Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ![screenshot_1st%20page.png](attachment:screenshot_1st%20page.png)
